# %%
names_A = [s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A')]
names_LL = [s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL')]
names_RL = [s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL')]
names_TA = [s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA')]
names_W = [s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W')]

# %%
import cv2
import numpy as np
from skimage.util import random_noise
import os as os

# RAW IMAGES
# extract the images 
data_A = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A')]
data_LL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL')]
data_RL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL')]
data_TA = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA')]
data_W = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W')]
images_A = []

images_A = []
for x in range(len(data_A)):
    img = cv2.imread(data_A[x],0)
    noise_img = random_noise(img, mode='gaussian', var=0.9, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_A.append(noise_img)
    
images_LL = []
for x in range(len(data_LL)):
    img = cv2.imread(data_LL[x],0)
    noise_img = random_noise(img, mode='gaussian', var=0.9, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_LL.append(noise_img)
    
images_RL = []
for x in range(len(data_RL)):
    img = cv2.imread(data_RL[x],0)
    noise_img = random_noise(img, mode='gaussian', var=0.9, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_RL.append(noise_img)
    
images_TA = []
for x in range(len(data_TA)):
    img = cv2.imread(data_TA[x],0)
    noise_img = random_noise(img, mode='gaussian', var=0.9, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_TA.append(noise_img)
    
images_W = []
for x in range(len(data_W)):
    img = cv2.imread(data_W[x],0)
    noise_img = random_noise(img, mode='gaussian', var=0.9, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_W.append(noise_img)

# %%
import cv2
import os
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Gaussian - 0.9/RAW/Test/A')
for x in range(len(images_A)):
    cv2.imwrite(names_A[x],images_A[x])

os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Gaussian - 0.9/RAW/Test/LL')
for x in range(len(images_LL)):
    cv2.imwrite(names_LL[x],images_LL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Gaussian - 0.9/RAW/Test/RL')
for x in range(len(images_RL)):
    cv2.imwrite(names_RL[x],images_RL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Gaussian - 0.9/RAW/Test/TA')
for x in range(len(images_TA)):
    cv2.imwrite(names_TA[x],images_TA[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Gaussian - 0.9/RAW/Test/W')
for x in range(len(images_W)):
    cv2.imwrite(names_W[x],images_W[x])

# %%
import cv2
import numpy as np
from skimage.util import random_noise
import os as os

# RAW IMAGES
# extract the images 
data_A = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A')]
data_LL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL')]
data_RL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL')]
data_TA = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA')]
data_W = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W')]
images_A = []

images_A = []
for x in range(len(data_A)):
    img = cv2.imread(data_A[x],0)
    noise_img = random_noise(img, mode='salt', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_A.append(noise_img)
    
images_LL = []
for x in range(len(data_LL)):
    img = cv2.imread(data_LL[x],0)
    noise_img = random_noise(img, mode='salt', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_LL.append(noise_img)
    
images_RL = []
for x in range(len(data_RL)):
    img = cv2.imread(data_RL[x],0)
    noise_img = random_noise(img, mode='salt', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_RL.append(noise_img)
    
images_TA = []
for x in range(len(data_TA)):
    img = cv2.imread(data_TA[x],0)
    noise_img = random_noise(img, mode='salt', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_TA.append(noise_img)
    
images_W = []
for x in range(len(data_W)):
    img = cv2.imread(data_W[x],0)
    noise_img = random_noise(img, mode='salt', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_W.append(noise_img)

# %%
import cv2
import os
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Salt - 0.9/RAW/Test/A')
for x in range(len(images_A)):
    cv2.imwrite(names_A[x],images_A[x])

os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Salt - 0.9/RAW/Test/LL')
for x in range(len(images_LL)):
    cv2.imwrite(names_LL[x],images_LL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Salt - 0.9/RAW/Test/RL')
for x in range(len(images_RL)):
    cv2.imwrite(names_RL[x],images_RL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Salt - 0.9/RAW/Test/TA')
for x in range(len(images_TA)):
    cv2.imwrite(names_TA[x],images_TA[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Salt - 0.9/RAW/Test/W')
for x in range(len(images_W)):
    cv2.imwrite(names_W[x],images_W[x])

# %%
import cv2
import numpy as np
from skimage.util import random_noise
import os as os

# RAW IMAGES
# extract the images 
data_A = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A')]
data_LL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL')]
data_RL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL')]
data_TA = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA')]
data_W = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W')]
images_A = []

images_A = []
for x in range(len(data_A)):
    img = cv2.imread(data_A[x],0)
    noise_img = random_noise(img, mode='pepper', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_A.append(noise_img)
    
images_LL = []
for x in range(len(data_LL)):
    img = cv2.imread(data_LL[x],0)
    noise_img = random_noise(img, mode='pepper', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_LL.append(noise_img)
    
images_RL = []
for x in range(len(data_RL)):
    img = cv2.imread(data_RL[x],0)
    noise_img = random_noise(img, mode='pepper', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_RL.append(noise_img)
    
images_TA = []
for x in range(len(data_TA)):
    img = cv2.imread(data_TA[x],0)
    noise_img = random_noise(img, mode='pepper', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_TA.append(noise_img)
    
images_W = []
for x in range(len(data_W)):
    img = cv2.imread(data_W[x],0)
    noise_img = random_noise(img, mode='pepper', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_W.append(noise_img)

# %%
import cv2
import os
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.9/RAW/Test/A')
for x in range(len(images_A)):
    cv2.imwrite(names_A[x],images_A[x])

os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.9/RAW/Test/LL')
for x in range(len(images_LL)):
    cv2.imwrite(names_LL[x],images_LL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.9/RAW/Test/RL')
for x in range(len(images_RL)):
    cv2.imwrite(names_RL[x],images_RL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.9/RAW/Test/TA')
for x in range(len(images_TA)):
    cv2.imwrite(names_TA[x],images_TA[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.9/RAW/Test/W')
for x in range(len(images_W)):
    cv2.imwrite(names_W[x],images_W[x])

# %%
import cv2
import numpy as np
from skimage.util import random_noise
import os as os

# RAW IMAGES
# extract the images 
data_A = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A')]
data_LL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL')]
data_RL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL')]
data_TA = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA')]
data_W = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W')]
images_A = []

images_A = []
for x in range(len(data_A)):
    img = cv2.imread(data_A[x],0)
    noise_img = random_noise(img, mode='s&p', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_A.append(noise_img)
    
images_LL = []
for x in range(len(data_LL)):
    img = cv2.imread(data_LL[x],0)
    noise_img = random_noise(img, mode='s&p', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_LL.append(noise_img)
    
images_RL = []
for x in range(len(data_RL)):
    img = cv2.imread(data_RL[x],0)
    noise_img = random_noise(img, mode='s&p', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_RL.append(noise_img)
    
images_TA = []
for x in range(len(data_TA)):
    img = cv2.imread(data_TA[x],0)
    noise_img = random_noise(img, mode='s&p', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_TA.append(noise_img)
    
images_W = []
for x in range(len(data_W)):
    img = cv2.imread(data_W[x],0)
    noise_img = random_noise(img, mode='s&p', seed=42, clip=True,amount=0.9)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_W.append(noise_img)

# %%
import cv2
import os
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.9/RAW/Test/A')
for x in range(len(images_A)):
    cv2.imwrite(names_A[x],images_A[x])

os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.9/RAW/Test/LL')
for x in range(len(images_LL)):
    cv2.imwrite(names_LL[x],images_LL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.9/RAW/Test/RL')
for x in range(len(images_RL)):
    cv2.imwrite(names_RL[x],images_RL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.9/RAW/Test/TA')
for x in range(len(images_TA)):
    cv2.imwrite(names_TA[x],images_TA[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.9/RAW/Test/W')
for x in range(len(images_W)):
    cv2.imwrite(names_W[x],images_W[x])

# %%
import cv2
import numpy as np
from skimage.util import random_noise
import os
data = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/TEST/LEONA/Ink/RAW/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/TEST/LEONA/Ink/RAW')]
images = []
for x in range(len(data)):
    img = cv2.imread(data[x],0)
    noise_img = random_noise(img, mode='pepper', seed=42, clip=True,amount=0.15)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images.append(noise_img)

names = [s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/TEST/LEONA/Ink/RAW')]
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/TEST/LEONA/Ink/PEPPER/0.15/RAW')
for x in range(len(images)):
    cv2.imwrite(names[x],images[x])

# %%
import cv2
import numpy as np
from skimage.util import random_noise
import os
data = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/TEST/LEONA/Ink/RAW/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/TEST/LEONA/Ink/RAW')]
images = []
for x in range(len(data)):
    img = cv2.imread(data[x],0)
    noise_img = random_noise(img, mode='s&p', amount = 0.35, salt_vs_pepper=0.8, seed=51, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images.append(noise_img)

names = [s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/TEST/LEONA/Ink/RAW')]
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/TEST/LEONA/Ink/S&P/0.35, R0.8 (10)/RAW')
for x in range(len(images)):
    cv2.imwrite(names[x],images[x])

# %%
import cv2
import numpy as np
from skimage.util import random_noise
import os as os
# RAW IMAGES
# extract the images 
data_A = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A')]
data_LL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL')]
data_RL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL')]
data_TA = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA')]
data_W = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W')]
images_A = []
for x in range(len(data_A)):
    img = cv2.imread(data_A[x],0)
    noise_img = random_noise(img, mode='pepper', amount = 0.15, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_A.append(noise_img)
    
images_LL = []
for x in range(len(data_LL)):
    img = cv2.imread(data_LL[x],0)
    noise_img = random_noise(img, mode='pepper', amount = 0.15, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_LL.append(noise_img)
    
images_RL = []
for x in range(len(data_RL)):
    img = cv2.imread(data_RL[x],0)
    noise_img = random_noise(img, mode='pepper', amount = 0.15, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_RL.append(noise_img)
    
images_TA = []
for x in range(len(data_TA)):
    img = cv2.imread(data_TA[x],0)
    noise_img = random_noise(img, mode='pepper', amount = 0.15, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_TA.append(noise_img)
    
images_W = []
for x in range(len(data_W)):
    img = cv2.imread(data_W[x],0)
    noise_img = random_noise(img, mode='pepper', amount = 0.15, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_W.append(noise_img)

# %%
import cv2
import os
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.15/RAW/Test/A')
for x in range(len(images_A)):
    cv2.imwrite(names_A[x],images_A[x])

os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.15/RAW/Test/LL')
for x in range(len(images_LL)):
    cv2.imwrite(names_LL[x],images_LL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.15/RAW/Test/RL')
for x in range(len(images_RL)):
    cv2.imwrite(names_RL[x],images_RL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.15/RAW/Test/TA')
for x in range(len(images_TA)):
    cv2.imwrite(names_TA[x],images_TA[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - Pepper - 0.15/RAW/Test/W')
for x in range(len(images_W)):
    cv2.imwrite(names_W[x],images_W[x])

# %%
import cv2
import numpy as np
from skimage.util import random_noise
import os as os
# RAW IMAGES
# extract the images 
data_A = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/A')]
data_LL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/LL')]
data_RL = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/RL')]
data_TA = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/TA')]
data_W = ['C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W/' + s for s in os.listdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw/Test/W')]
images_A = []
for x in range(len(data_A)):
    img = cv2.imread(data_A[x],0)
    noise_img = random_noise(img, mode='s&p', amount = 0.35, salt_vs_pepper=0.8, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_A.append(noise_img)
    
images_LL = []
for x in range(len(data_LL)):
    img = cv2.imread(data_LL[x],0)
    noise_img = random_noise(img, mode='s&p', amount = 0.35, salt_vs_pepper=0.8, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_LL.append(noise_img)
    
images_RL = []
for x in range(len(data_RL)):
    img = cv2.imread(data_RL[x],0)
    noise_img = random_noise(img, mode='s&p', amount = 0.35, salt_vs_pepper=0.8, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_RL.append(noise_img)
    
images_TA = []
for x in range(len(data_TA)):
    img = cv2.imread(data_TA[x],0)
    noise_img = random_noise(img, mode='s&p', amount = 0.35, salt_vs_pepper=0.8, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_TA.append(noise_img)
    
images_W = []
for x in range(len(data_W)):
    img = cv2.imread(data_W[x],0)
    noise_img = random_noise(img, mode='s&p', amount = 0.35, salt_vs_pepper=0.8, seed=42, clip=True)
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    images_W.append(noise_img)

# %%
import cv2
import os
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.3R0.8/RAW/Test/A')
for x in range(len(images_A)):
    cv2.imwrite(names_A[x],images_A[x])

os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.3R0.8/RAW/Test/LL')
for x in range(len(images_LL)):
    cv2.imwrite(names_LL[x],images_LL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.3R0.8/RAW/Test/RL')
for x in range(len(images_RL)):
    cv2.imwrite(names_RL[x],images_RL[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.3R0.8/RAW/Test/TA')
for x in range(len(images_TA)):
    cv2.imwrite(names_TA[x],images_TA[x])
    
os.chdir('C:/Users/leona/OneDrive/DSA4199/NIST-Classification/Training - Raw - S&P - 0.3R0.8/RAW/Test/W')
for x in range(len(images_W)):
    cv2.imwrite(names_W[x],images_W[x])
